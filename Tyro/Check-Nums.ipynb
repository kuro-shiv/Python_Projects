# %%
def CheckNums(num1, num2):
    if num2 > num1:
        return "true"
    elif num1 > num2:
        return "false"
    else:
        return -1

# %%
CheckNums(3,2)
# Out:
# 'false'

# %%
CheckNums(1,2)
# Out:
# 'true'

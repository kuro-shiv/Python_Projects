# %%
def TimeConvert(num):
    minutes = num % 60
    hours = (num - minutes)/60
    res = str(hours) + ":" + str(minutes)
    return res

# %%
TimeConvert(100)
# Out:
# '1.0:40'

# %%
TimeConvert(10)
# Out:
# '0.0:10'
